# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\bisha\\OneDrive\\Documents\\GitHub\\Cantek_Python_Practice\\Project_3_SQL_Python\\3_visuals_csv.csv")

# %%
csv_location="C:\\Users\\bisha\\OneDrive\\Documents\\GitHub\\Cantek_Python_Practice\\Project_3_SQL_Python\\3_visuals_csv.csv"

# %%
df=pd.read_csv(csv_location)

# %% [raw]
# df

# %%
df
# Out:
#                   country  total_revenue
# 0                Thailand         401.08
# 1    Virgin Islands, U.S.         121.69
# 2           Faroe Islands          96.76
# 3              Bangladesh         353.19
# 4               Indonesia        1352.69
# ..                    ...            ...
# 103              Tanzania         322.22
# 104                Poland         786.16
# 105                Taiwan        1155.10
# 106         French Guiana          97.80
# 107             Greenland         119.72
#
# [108 rows x 2 columns]

# %%
# Plotting the bar graph
plt.figure(figsize= (35, 6))
plt.bar(df["country"],df["total_revenue"])
# Customize the plot
plt.xlabel('Country')
plt.ylabel('Revenue')
plt.title('Revenue by Country')
plt.xticks(rotation=90, fontweight='light')
# Show the plot
plt.show()
